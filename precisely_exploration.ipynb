# %% [markdown]
# # Precisely Geodata Exploration

# %% [markdown]
# Working with data available through the [Precisely Data Experience sample datasets](https://data.precisely.com/samples). Specifically, `School Boundaries USA` downloaded in Shape format.
#
# Schema:
# https://docs.google.com/spreadsheets/d/18CDcZxSHvGXVVMDstur1yrHyum8i4qA4/edit#gid=782773548
#
# **NOTE**: You may use [nbviewer](https://nbviewer.org/) to view this notebook outside your local Jupyter environment.
# [Click here](https://nbviewer.org/github/PMattox/fs/blob/main/precisely_exploration.ipynb)

# %%
# pip install geopandas

# %%
# pip install folium

# %%
# IMPORTS
import geopandas as gpd
import pandas as pd

import os
import urllib.request
import requests
import shutil
from pathlib import Path
from zipfile import ZipFile

import matplotlib.pyplot as plt
from matplotlib import pyplot

import folium

from shapely.geometry import Point, Polygon

# %% [markdown]
# ## School Boundaries (Shapefile)

# %%
filepath = '/Users/preston.mattox@finalsite.com/Downloads/SCHOOL_BOUNDARIES_USA_202312_SHP_SAMPLE/data/'
file = 'school_attendance_zone_objects_usa_sample.shp'

# %%
saz = gpd.read_file(filepath+file)

# column names to lowercase
saz.columns= saz.columns.str.lower()

saz.head(3)
# Out:
#      obj_id                        obj_name obj_typ obj_subtcd  \
# 0  16074983  QUAIL HOLLOW ELEMENTARY SCHOOL  School        SAZ
# 1  16074985   SILVER MESA ELEMENTARY SCHOOL  School        SAZ
# 2  16074987     MIDVALLEY ELEMENTARY SCHOOL  School        SAZ
#
#                obj_subtyp country               metro        lat         lon  \
# 0  School Attendance Zone     USA  Salt Lake City, UT  40.585586 -111.821031
# 1  School Attendance Zone     USA  Salt Lake City, UT  40.587210 -111.844863
# 2  School Attendance Zone     USA  Salt Lake City, UT  40.610288 -111.880360
#
#     reldate     obj_area                                           geometry
# 0  20231126  2885227.634  POLYGON ((-111.82347 40.59148, -111.82293 40.5...
# 1  20231126  2926275.545  POLYGON ((-111.83516 40.59361, -111.83488 40.5...
# 2  20231126  4316524.948  POLYGON ((-111.86597 40.62190, -111.86599 40.6...

# %%
# examine datatypes within the dataset
print(saz.geom_type.unique())
print(saz.dtypes)
# Out:
# ['Polygon' 'MultiPolygon']
# obj_id           int64
# obj_name        object
# obj_typ         object
# obj_subtcd      object
# obj_subtyp      object
# country         object
# metro           object
# lat            float64
# lon            float64
# reldate         object
# obj_area       float64
# geometry      geometry
# dtype: object

# %%
# plot the data on a map via folium

# create a base map centered on Salt Lake City, UT
map_saz = folium.Map(
    location=[40.68, -111.89],
    zoom_start=10,
)

# set up the annotations
tooltip = folium.GeoJsonTooltip(
    fields=["obj_name"],
    aliases=["School:"],
    localize=True,
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=800,
)

# add the school zones on the map
folium.GeoJson(saz[['geometry','obj_name']], 
               style_function=lambda feature: {'fillColor': '#2196F3', 'color': '#2196F3'},
              tooltip=tooltip
              ).add_to(map_saz)

# display the map
map_saz
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6095c27ba5c65551c5e2a4e275389993 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
.8212743, 40.5772589], [-111.8214526, 40.5773563], [-111.8215778, 40.5774302], [-111.8217528, 40.5775453], [-111.8218984, 40.5776497], [-111.8222403, 40.5779052], [-111.8226936, 40.5782503], [-111.8231119, 40.57857], [-111.823557, 40.5789003], [-111.8236924, 40.5789879], [-111.8239591, 40.5791378], [-111.8241498, 40.5792414], [-111.8243755, 40.5793672], [-111.8246264, 40.5794897], [-111.8248051, 40.5795698], [-111.825185, 40.5797286], [-111.8257919, 40.5799634], [-111.8260471, 40.5800617], [-111.8263221, 40.5801538], [-111.8265195, 40.5802079], [-111.8266978, 40.5802483], [-111.8269654, 40.5803005], [-111.8271179, 40.5803274], [-111.8274658, 40.5803792], [-111.8277184, 40.5804083], [-111.8279856, 40.5804331], [-111.82

# %%
# plot a random subset for easier examination

# create a base map centered on Salt Lake City, UT
map_saz = folium.Map(
    location=[40.68, -111.89],
    zoom_start=10,
)

# set up the annotations
tooltip = folium.GeoJsonTooltip(
    fields=["obj_name"],
    aliases=["School:"],
    localize=True,
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=800,
)

# add the school zones on the map
folium.GeoJson(saz[['geometry','obj_name']].sample(5), 
               style_function=lambda feature: {'fillColor': '#2196F3', 'color': '#2196F3'},
              tooltip=tooltip
              ).add_to(map_saz)

# display the map
map_saz
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c770415bb3b5e28d73ada02f7cc85aa5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#         background-color: #F0EFEF;
#         border: 2px solid black;
#         border-radius: 3px;
#         box-shadow: 3px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c770415bb3b5e28d73ada02f7cc85aa5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c770415bb3b5e28d73ada02f7cc85aa5 = L.map(
#                 &quot;map_c770415bb3b5e28d73ada02f7cc85aa5&quot;,
#                 {
#                     center: [40.68, -111.89],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6be870af92bbd8621dade5bf3c6ca877 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6be870af92bbd8621dade5bf3c6ca877.addTo(map_c770415bb3b5e28d73ada02f7cc85aa5);
#
#
#         function geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#2196F3&quot;, &quot;fillColor&quot;: &quot;#2196F3&quot;};
#             }
#         }
#
#         function geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b = L.geoJson(null, {
#                 onEachFeature: geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b_onEachFeature,
#
#                 style: geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b_styler,
#         });
#
#         function geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b_add (data) {
#             geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b
#                 .addData(data);
#         }
#             geo_json_0c4abcf3d8d52f1bf2f52ce88e27fe8b_add({&quot;bbox&quot;: [-112.024573, 40.451624, -111.780984, 40.769443], &quot;features&quot;: [{&quot;bbox&quot;: [-111.9916379, 40.4624343, -111.9151911, 40.5024548], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[
# 2  52747563    16075475    15117254        KG           6
# 3  52747753    16075521    15117308        KG           6
# 4  52748050    16075317    15117200        07           8

# %%
# join with the attributes data to get low/high grades
saz_all_att = saz.join(saz_t.set_index('obj_id_saz'), on='obj_id', how='inner')
saz_all_att.head(3)
# Out:
#      obj_id                        obj_name obj_typ obj_subtcd  \
# 0  16074983  QUAIL HOLLOW ELEMENTARY SCHOOL  School        SAZ
# 1  16074985   SILVER MESA ELEMENTARY SCHOOL  School        SAZ
# 2  16074987     MIDVALLEY ELEMENTARY SCHOOL  School        SAZ
#
#                obj_subtyp country               metro        lat         lon  \
# 0  School Attendance Zone     USA  Salt Lake City, UT  40.585586 -111.821031
# 1  School Attendance Zone     USA  Salt Lake City, UT  40.587210 -111.844863
# 2  School Attendance Zone     USA  Salt Lake City, UT  40.610288 -111.880360
#
#     reldate     obj_area                                           geometry  \
# 0  20231126  2885227.634  POLYGON ((-111.82347 40.59148, -111.82293 40.5...
# 1  20231126  2926275.545  POLYGON ((-111.83516 40.59361, -111.83488 40.5...
# 2  20231126  4316524.948  POLYGON ((-111.86597 40.62190, -111.86599 40.6...
#
#      att_id  obj_id_pnt low_grade  high_grade
# 0  52785550    15116961        PK           5
# 1  52755754    15116955        KG           5
# 2  52756111    15116944        KG           5

# %%
# now add data about the schools themselves (i.e. the "point data")
file_s_att = 'school_point_primary_attributes_usa_sample.csv'
s_att = pd.read_csv(filepath+file_s_att)
s_att.head()
# Out:
#      obj_id    nces_schid  nces_disid  grtschl_id  choice  coextensiv  \
# 0  15116924  490014200286     4900142   4902028.0   False       False
# 1  15116926  490014200288     4900142   4902030.0   False       False
# 2  15116927  490014200291     4900142   4902031.0   False       False
# 3  15116928  490014200292     4900142   4902032.0   False       False
# 4  15116929  490014200293     4900142   4902033.0   False       False
#
#    students  teachers     pk     kg  ...  eighth  ninth  tenth  eleventh  \
# 0     581.0     26.00  False   True  ...   False  False  False     False
# 1     227.0     17.00  False   True  ...   False  False  False     False
# 2    2240.0     82.96  False  False  ...   False   True   True      True
# 3     418.0     18.50  False   True  ...   False  False  False     False
# 4     896.0     39.25  False  False  ...    True  False  False     False
#
#    twelfth  low_grade  high_grade  gender  school_typ  ed_level
# 0    False         KG           5     NaN           R         P
# 1    False         KG           5     NaN           R         P
# 2     True         09          12     NaN           R         H
# 3    False         KG           5     NaN           R         P
# 4    False         06           8     NaN           R         M
#
# [5 rows x 27 columns]

# %%
# bring it all together into one mega df
s_att = s_att.rename(columns={"low_grade": "low_grade_att", "high_grade": "high_grade_att"}, errors="raise")

saz_all_att = saz_all_att.join(s_att.set_index('obj_id'), on='obj_id_pnt', how='inner')
saz_all_att
# Out:
#        obj_id                          obj_name obj_typ obj_subtcd  \
# 0    16074983    QUAIL HOLLOW ELEMENTARY SCHOOL  School        SAZ
# 1    16074985     SILVER MESA ELEMENTARY SCHOOL  School        SAZ
# 2    16074987       MIDVALLEY ELEMENTARY SCHOOL  School        SAZ
# 3    16075168         ELK RUN ELEMENTARY SCHOOL  School        SAZ
# 4    16075170    ACADEMY PARK ELEMENTARY SCHOOL  School        SAZ
# ..        ...                               ...     ...        ...
# 220  16360273           OLENE WALKER ELEMENTARY  School        SAZ
# 221  16360449  MOUNTAIN POINT ELEMENTARY SCHOOL  School        SAZ
# 222  16363218           ASPEN ELEMENTARY SCHOOL  School        SAZ
# 223  16363219        OAK LEAF ELEMENTARY SCHOOL  School        SAZ
# 224  16375750          GLACIER HILLS ELEMENTARY  School        SAZ
#
#                  obj_subtyp country               metro        lat  \
# 0    School Attendance Zone     USA  Salt Lake City, UT  40.585586
# 1    School Attendance Zone     USA  Salt Lake City, UT  40.587210
# 2    School Attendance Zone     USA  Salt Lake City, UT  40.610288
# 3    School Attendance Zone     USA                None  40.676653
# 4    School Attendance Zone     USA  Salt Lake City, UT  40.673413
# ..                      ...     ...                 ...        ...
# 220  School Attendance Zone     USA  Salt Lake City, UT  40.694575
# 221  School Attendance Zone     USA                None  40.452802
# 222  School Attendance Zone     USA                None  40.531711
# 223  School Attendance Zone     USA                None  40.506730
# 224  School Attendance Zone     USA  Salt Lake City, UT  40.575392
#
#             lon   reldate  ...  eighth  ninth  tenth  eleventh twelfth  \
# 0   -111.821031  20231126  ...   False  False  False     False   False
# 1   -111.844863  20231126  ...   False  False  False     False   False
# 2   -111.880360  20231126  ...   False  False  False     False   False
# 3   -112.144352  20231126  ...   False  False  False     False   False
# 4   -112.000957  20231126  ...   False  False  False     False   False
# ..          ...       ...  ...     ...    ...    ...       ...     ...
# 220 -111.907703  20231126  ...   False  False  False     False   False
# 221 -111.959201  20231126  ...   False  False  False     False   False
# 222 -112.115001  20231126  ...   False  False  False     False   False
# 223 -112.077923  20231126  ...   False  False  False     False   False
# 224 -111.874031  20231126  ...   False  False  False     False   False
#
#      low_grade_att high_grade_att  gender  school_typ  ed_level
# 0               PK              5     NaN           R         P
# 1               KG              5     NaN           R         P
# 2               KG              5     NaN           R         P
# 3               KG              6     NaN           R        PM
# 4               KG              6     NaN           R        PM
# ..             ...            ...     ...         ...       ...
# 220             KG              5     NaN           R         P
# 221             KG              6     NaN           R        PM
# 222             KG              6     NaN           R        PM
# 223             KG              6     NaN           R        PM
# 224             KG              5     NaN           R         P
#
# [225 rows x 42 columns]

# %%
# what columns did we end up with?
saz_all_att.columns
# Out:
# Index(['obj_id', 'obj_name', 'obj_typ', 'obj_subtcd', 'obj_subtyp', 'country',
#        'metro', 'lat', 'lon', 'reldate', 'obj_area', 'geometry', 'att_id',
#        'obj_id_pnt', 'low_grade', 'high_grade', 'nces_schid', 'nces_disid',
#        'grtschl_id', 'choice', 'coextensiv', 'students', 'teachers', 'pk',
#        'kg', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh',
#        'eighth', 'ninth', 'tenth', 'eleventh', 'twelfth', 'low_grade_att',
#        'high_grade_att', 'gender', 'school_typ', 'ed_level'],
#       dtype='object')

# %%
# focus in on a few columns that we care about
saz_all_att[['obj_id', 'obj_name','geometry','nces_schid', 
             'students', 'teachers', 'pk',  'low_grade', 'high_grade', 'low_grade_att','high_grade_att']]
# Out:
#        obj_id                          obj_name  \
# 0    16074983    QUAIL HOLLOW ELEMENTARY SCHOOL
# 1    16074985     SILVER MESA ELEMENTARY SCHOOL
# 2    16074987       MIDVALLEY ELEMENTARY SCHOOL
# 3    16075168         ELK RUN ELEMENTARY SCHOOL
# 4    16075170    ACADEMY PARK ELEMENTARY SCHOOL
# ..        ...                               ...
# 220  16360273           OLENE WALKER ELEMENTARY
# 221  16360449  MOUNTAIN POINT ELEMENTARY SCHOOL
# 222  16363218           ASPEN ELEMENTARY SCHOOL
# 223  16363219        OAK LEAF ELEMENTARY SCHOOL
# 224  16375750          GLACIER HILLS ELEMENTARY
#
#                                               geometry    nces_schid  \
# 0    POLYGON ((-111.82347 40.59148, -111.82293 40.5...  490014200768
# 1    POLYGON ((-111.83516 40.59361, -111.83488 40.5...  490014200658
# 2    POLYGON ((-111.86597 40.62190, -111.86599 40.6...  490014200313
# 3    POLYGON ((-112.11084 40.70057, -112.11012 40.7...  490036001412
# 4    POLYGON ((-111.98659 40.67595, -111.98660 40.6...  490036000196
# ..                                                 ...           ...
# 220  POLYGON ((-111.90699 40.70712, -111.90678 40.7...  4900360XXX33
# 221  POLYGON ((-111.91356 40.48984, -111.91280 40.4...  490042001543
# 222  POLYGON ((-112.03289 40.56597, -112.03198 40.5...  490042001568
# 223  POLYGON ((-112.03734 40.52239, -112.03695 40.5...  4900420XXX01
# 224  POLYGON ((-111.85841 40.58708, -111.85850 40.5...  4900142XXX07
#
#      students  teachers     pk low_grade  high_grade low_grade_att  \
# 0       479.0     25.23   True        PK           5            PK
# 1       570.0     25.48  False        KG           5            KG
# 2       496.0     23.50  False        KG           5            KG
# 3       645.0     26.31  False        KG           6            KG
# 4       376.0     19.00  False        KG           6            KG
# ..        ...       ...    ...       ...         ...           ...
# 220       0.0       NaN  False        KG           5            KG
# 221     686.0     28.63  False        KG           6            KG
# 222     501.0     21.95  False        KG           6            KG
# 223       0.0       NaN  False        KG           6            KG
# 224       NaN       NaN  False        KG           5            KG
#
#      high_grade_att
# 0                 5
# 1                 5
# 2                 5
# 3                 6
# 4                 6
# ..              ...
# 220               5
# 221               6
# 222               6
# 223               6
# 224               5
#
# [225 rows x 11 columns]

# %%
# as a check, make sure all the low grades from both tables match
saz_all_att.apply(lambda row: all(i in row.low_grade_att for i in row.low_grade), axis=1).sort_values
# Out:
# <bound method Series.sort_values of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 220    True
# 221    True
# 222    True
# 223    True
# 224    True
# Length: 225, dtype: bool>

# %%
# as a check, make sure all the HIGH grades from both tables match
saz_all_att.apply(lambda row: all(i in str(row.high_grade_att) for i in str(row.high_grade)), axis=1).sort_values
# Out:
# <bound method Series.sort_values of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 220    True
# 221    True
# 222    True
# 223    True
# 224    True
# Length: 225, dtype: bool>

# %% [markdown]
# ### External validation of this joined data
#
# We can use the [NCES school search](https://nces.ed.gov/ccd/schoolsearch/) to spot check these.

# %% [markdown]
# `490014200768` should resolve to [Quail Hollow Elementary](https://nces.ed.gov/ccd/schoolsearch/school_list.asp?Search=1&InstName=&SchoolID=490014200768&Address=&City=&State=&Zip=&Miles=&County=&PhoneAreaCode=&Phone=&DistrictName=&DistrictID=&SchoolType=1&SchoolType=2&SchoolType=3&SchoolType=4&SpecificSchlTypes=all&IncGrade=-1&LoGrade=-1&HiGrade=-1), serving grades K-5.

# %%
# pull Quail Hollow Elementary's NCES ID into from our df
test1 = saz_all_att.loc[saz_all_att['nces_schid'].isin(['490014200768'])][[
            'obj_id', 'obj_name','nces_schid','low_grade','high_grade','geometry']]
test1
# Out:
#      obj_id                        obj_name    nces_schid low_grade  \
# 0  16074983  QUAIL HOLLOW ELEMENTARY SCHOOL  490014200768        PK
#
#    high_grade                                           geometry
# 0           5  POLYGON ((-111.82347 40.59148, -111.82293 40.5...

# %%
# map Quail Hollow Elementary
# create a base map centered on Salt Lake City, UT
map_test1 = folium.Map(
    location=[40.68, -111.89],
    zoom_start=10,
)

# set up the annotations
tooltip = folium.GeoJsonTooltip(
    fields=["obj_name", "low_grade", "high_grade"],
    aliases=["School:", "Low Grade:", "High Grade:"],
    localize=True,
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=800,
)

# add the school zones on the map
folium.GeoJson(test1, 
               style_function=lambda feature: {'fillColor': '#2196F3', 'color': '#2196F3'},
              tooltip=tooltip
              ).add_to(map_test1)

# find the bounds of this one poly and adjust the zoom to match
bounds = test1.total_bounds.tolist()
map_test1.fit_bounds([bounds[:2][::-1], bounds[2:][::-1]])

# display the map
map_test1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94a2de27aa1370a7a829d13cf65c2a2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#         background-color: #F0EFEF;
#         border: 2px solid black;
#         border-radius: 3px;
#         box-shadow: 3px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94a2de27aa1370a7a829d13cf65c2a2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94a2de27aa1370a7a829d13cf65c2a2c = L.map(
#                 &quot;map_94a2de27aa1370a7a829d13cf65c2a2c&quot;,
#                 {
#                     center: [40.68, -111.89],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d84696256f0873612a57d8de7ea915b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d84696256f0873612a57d8de7ea915b8.addTo(map_94a2de27aa1370a7a829d13cf65c2a2c);
#
#
#         function geo_json_84b0b18c33a5547487332a10c90ea722_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#2196F3&quot;, &quot;fillColor&quot;: &quot;#2196F3&quot;};
#             }
#         }
#
#         function geo_json_84b0b18c33a5547487332a10c90ea722_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_84b0b18c33a5547487332a10c90ea722 = L.geoJson(null, {
#                 onEachFeature: geo_json_84b0b18c33a5547487332a10c90ea722_onEachFeature,
#
#                 style: geo_json_84b0b18c33a5547487332a10c90ea722_styler,
#         });
#
#         function geo_json_84b0b18c33a5547487332a10c90ea722_add (data) {
#             geo_json_84b0b18c33a5547487332a10c90ea722
#                 .addData(data);
#         }
#             geo_json_84b0b18c33a5547487332a10c90ea722_add({&quot;bbox&quot;: [-111.8341784, 40.5770989, -111.8042222, 40.5922803], &quot;features&quot;: [{&quot;bbox&quot;: [-111.8341784, 40.5770989, -111.8042222, 40.5922803], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[
# Columns: [obj_id, obj_name, obj_typ, obj_subtcd, obj_subtyp, country, metro, lat, lon, reldate, obj_area, geometry, att_id, obj_id_pnt, low_grade, high_grade, nces_schid, nces_disid, grtschl_id, choice, coextensiv, students, teachers, pk, kg, first, second, third, fourth, fifth, sixth, seventh, eighth, ninth, tenth, eleventh, twelfth, low_grade_att, high_grade_att, gender, school_typ, ed_level]
# Index: []
#
# [0 rows x 42 columns]

# %%
# ...but Olene Walker Elementary definiely is in our dataset
saz_all_att[saz_all_att['obj_name'].str.contains('OLENE', regex=True)][[
            'obj_id', 'obj_name','nces_schid','low_grade','high_grade','geometry']]
# Out:
#        obj_id                 obj_name    nces_schid low_grade  high_grade  \
# 220  16360273  OLENE WALKER ELEMENTARY  4900360XXX33        KG           5
#
#                                               geometry
# 220  POLYGON ((-111.90699 40.70712, -111.90678 40.7...

# %% [markdown]
# ----

# %% [markdown]
# # Demo
#
# As a demonstration of this data capability, grab a single random sample from the dataset and map it with supporting info.

# %%
df_demo = saz_all_att.sample(1)

# create a base map centered on Salt Lake City, UT
map_demo = folium.Map(
    location=[40.68, -111.89],
    zoom_start=10,
)

# set up the annotations
tooltip = folium.GeoJsonTooltip(
    fields=["obj_name", "low_grade", "high_grade"],
    aliases=["School:", "Low Grade:", "High Grade:"],
    localize=True,
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=800,
)

# add the school zones on the map
folium.GeoJson(df_demo, 
               style_function=lambda feature: {'fillColor': '#2196F3', 'color': '#2196F3'},
              tooltip=tooltip
              ).add_to(map_demo)

# find the bounds of this one poly and adjust the zoom to match
bounds = df_demo.total_bounds.tolist()
map_demo.fit_bounds([bounds[:2][::-1], bounds[2:][::-1]])

# display the 
map
map_demo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48f64d3594fc194108218df8ecac37db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#         background-color: #F0EFEF;
#         border: 2px solid black;
#         border-radius: 3px;
#         box-shadow: 3px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48f64d3594fc194108218df8ecac37db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48f64d3594fc194108218df8ecac37db = L.map(
#                 &quot;map_48f64d3594fc194108218df8ecac37db&quot;,
#                 {
#                     center: [40.68, -111.89],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a6eee184e3d52cf7f0cb97f98e62ed4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a6eee184e3d52cf7f0cb97f98e62ed4.addTo(map_48f64d3594fc194108218df8ecac37db);
#
#
#         function geo_json_230fa842f8ffeb235b54380c412b3a7b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#2196F3&quot;, &quot;fillColor&quot;: &quot;#2196F3&quot;};
#             }
#         }
#
#         function geo_json_230fa842f8ffeb235b54380c412b3a7b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_230fa842f8ffeb235b54380c412b3a7b = L.geoJson(null, {
#                 onEachFeature: geo_json_230fa842f8ffeb235b54380c412b3a7b_onEachFeature,
#
#                 style: geo_json_230fa842f8ffeb235b54380c412b3a7b_styler,
#         });
#
#         function geo_json_230fa842f8ffeb235b54380c412b3a7b_add (data) {
#             geo_json_230fa842f8ffeb235b54380c412b3a7b
#                 .addData(data);
#         }
#             geo_json_230fa842f8ffeb235b54380c412b3a7b_add({&quot;bbox&quot;: [-111.976445, 40.5797537, -111.9117724, 40.6315168], &quot;features&quot;: [{&quot;bbox&quot;: [-111.976445, 40.5797537, -111.9117724, 40.6315168], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[