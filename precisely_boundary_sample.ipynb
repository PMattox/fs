# %% [markdown]
# # Precisely Boundry Check Demo

# %% [markdown]
# Building on the Precisely boundary data info, now we can explore the FS use case:
# *Understand which schools are accessible/enrollable based on parent address.*
#
# "Parent address" will be turned into a geospatial location (latitude and longitude) via geocoding. We need to prove out the ability to use that location to determine which school enrollment zones the point falls within.
#
# **NOTE**: You may use [nbviewer](https://nbviewer.org/) to view this notebook outside your local Jupyter environment.

# %%
# IMPORTS
import geopandas as gpd
import pandas as pd

import os
import urllib.request
import requests
import shutil
from pathlib import Path
from zipfile import ZipFile

import matplotlib.pyplot as plt
from matplotlib import pyplot

import folium

from shapely.geometry import Point, Polygon

# %% [markdown]
# ## Data loading and joining

# %%
# find the file for school attendance zones
filepath = '/Users/preston.mattox@finalsite.com/Downloads/SCHOOL_BOUNDARIES_USA_202312_SHP_SAMPLE/data/'
file = 'school_attendance_zone_objects_usa_sample.shp'

# load school boundaries
saz = gpd.read_file(filepath+file)

# column names to lowercase
saz.columns= saz.columns.str.lower()

# %%
# find the file for attendance zone attributes
file_saz_t = 'school_attendance_zone_tertiary_attributes_usa_sample.csv'
saz_t = pd.read_csv(filepath+file_saz_t)
# saz_t.head()

# %%
# join with the attributes data to get low/high grades
saz_base_t = saz.join(saz_t.set_index('obj_id_saz'), on='obj_id', how='inner')
# saz_all_att.head(3)

# %%
# now add data about the schools themselves (i.e. the "point data")
file_s_att = 'school_point_primary_attributes_usa_sample.csv'
s_att = pd.read_csv(filepath+file_s_att)
# s_att.head()

# %%
# bring it all together into one mega df
s_att = s_att.rename(columns={"low_grade": "low_grade_att", "high_grade": "high_grade_att"}, errors="raise")

saz_all_att = saz_base_t.join(s_att.set_index('obj_id'), on='obj_id_pnt', how='inner')

# %%
# focus in on a few columns that we care about
saz_all_att[['obj_id', 'obj_name','geometry','nces_schid', 
             'students', 'teachers', 'pk',  'low_grade', 'high_grade', 'low_grade_att','high_grade_att']].head()
# Out:
#      obj_id                        obj_name  \
# 0  16074983  QUAIL HOLLOW ELEMENTARY SCHOOL
# 1  16074985   SILVER MESA ELEMENTARY SCHOOL
# 2  16074987     MIDVALLEY ELEMENTARY SCHOOL
# 3  16075168       ELK RUN ELEMENTARY SCHOOL
# 4  16075170  ACADEMY PARK ELEMENTARY SCHOOL
#
#                                             geometry    nces_schid  students  \
# 0  POLYGON ((-111.82347 40.59148, -111.82293 40.5...  490014200768     479.0
# 1  POLYGON ((-111.83516 40.59361, -111.83488 40.5...  490014200658     570.0
# 2  POLYGON ((-111.86597 40.62190, -111.86599 40.6...  490014200313     496.0
# 3  POLYGON ((-112.11084 40.70057, -112.11012 40.7...  490036001412     645.0
# 4  POLYGON ((-111.98659 40.67595, -111.98660 40.6...  490036000196     376.0
#
#    teachers     pk low_grade  high_grade low_grade_att  high_grade_att
# 0     25.23   True        PK           5            PK               5
# 1     25.48  False        KG           5            KG               5
# 2     23.50  False        KG           5            KG               5
# 3     26.31  False        KG           6            KG               6
# 4     19.00  False        KG           6            KG               6

# %% [markdown]
# ----

# %% [markdown]
# ### Carpentry for sorting
#
# Our grade columns are not set up in a way that allows for easy and correct sorting. Let's convert values to categoricals to resolve this.

# %%
# look at low grade values
saz_all_att['low_grade'].unique()
# Out:
# array(['PK', 'KG', '07', '06', '10', '09'], dtype=object)

# %%
# Define the custom ordering for low grades
custom_order = ['PK', 'KG', '01', '02', '03', '04', '05', '06', '07', '09', '10', '11', '12']

# Convert the low grade column to categorical with the custom ordering
saz_all_att['low_grade'] = pd.Categorical(saz_all_att['low_grade'], categories=custom_order, ordered=True)

# %%
# look at high grade values
saz_all_att['high_grade'].unique()
# Out:
# array([ 5,  6,  9,  8, 12])

# %%
# TODO: fix high grades so that they sort correctly

# %% [markdown]
# # Demo the school attendance zone identification use case

# %% [markdown]
# Create a df of latitude & longitude pairs in this area
#
# We can use [this resource](https://developers.google.com/maps/documentation/javascript/examples/event-click-latlng) to find sample points in our region of interest.

# %%
# we will later want to join these points with the above gdf
# let's grab the CRS from it and project our new coordinates in this space
target_crs = saz_all_att.crs

# %%
# Sample collection of latitude and longitude pairs
lat_lng_pairs = [
    { "lat": 40.5974125741681, "lng": -111.9354563470756 },
    { "lat": 40.6011924027903, "lng": -111.87932307681193 },
    { "lat": 40.61266091930544, "lng": -111.94944674929728 },
    # Add more latitude and longitude pairs as needed
]

# Create a GeoDataFrame
geometry = [Point(lng, lat) for lat, lng in zip([pair['lat'] for pair in lat_lng_pairs], [pair['lng'] for pair in lat_lng_pairs])]
gdf_points = gpd.GeoDataFrame(lat_lng_pairs, geometry=geometry, crs=target_crs)

# Add a new column "category" with value "home" and row index
gdf_points['label'] = 'home_sample_' + gdf_points.index.astype(str)

# Display the GeoDataFrame
gdf_points
# Out:
#          lat         lng                     geometry          label
# 0  40.597413 -111.935456  POINT (-111.93546 40.59741)  home_sample_0
# 1  40.601192 -111.879323  POINT (-111.87932 40.60119)  home_sample_1
# 2  40.612661 -111.949447  POINT (-111.94945 40.61266)  home_sample_2

# %%
# Create a Folium map centered around the points
m = folium.Map(location=[gdf_points.geometry.y.mean(), gdf_points.geometry.x.mean()], zoom_start=12)

# Add annotated points to the map    
for idx, row in gdf_points.iterrows():
    popup = row['label']
    folium.Marker(location=[row.geometry.y, row.geometry.x], popup=popup).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef2f66e1f83d7914ecafd0fa8f515cb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef2f66e1f83d7914ecafd0fa8f515cb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef2f66e1f83d7914ecafd0fa8f515cb1 = L.map(
#                 &quot;map_ef2f66e1f83d7914ecafd0fa8f515cb1&quot;,
#                 {
#                     center: [40.60375529875461, -111.92140872439494],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51803578766451d479392bdbd9261496 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_51803578766451d479392bdbd9261496.addTo(map_ef2f66e1f83d7914ecafd0fa8f515cb1);
#
#
#             var marker_d1ca15988f0ed781190fb7a3da9b4ef4 = L.marker(
#                 [40.5974125741681, -111.9354563470756],
#                 {}
#             ).addTo(map_ef2f66e1f83d7914ecafd0fa8f515cb1);
#
#
#         var popup_e8877f20b0cc539a57c322008cc2d3ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3211e845dfeb6c5835e33a996a676148 = $(`&lt;div id=&quot;html_3211e845dfeb6c5835e33a996a676148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;home_sample_0&lt;/div&gt;`)[0];
#                 popup_e8877f20b0cc539a57c322008cc2d3ee.setContent(html_3211e845dfeb6c5835e33a996a676148);
#
#
#
#         marker_d1ca15988f0ed781190fb7a3da9b4ef4.bindPopup(popup_e8877f20b0cc539a57c322008cc2d3ee)
#         ;
#
#
#
#
#             var marker_641e734c876a41ae22162bff058c18c3 = L.marker(
#                 [40.6011924027903, -111.87932307681193],
#                 {}
#             ).addTo(map_ef2f66e1f83d7914ecafd0fa8f515cb1);
#
#
#         var popup_7aea6d0bf64788279230f9cb15ea7f60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22b9a128e725f96f4459388645daaf70 = $(`&lt;div id=&quot;html_22b9a128e725f96f4459388645daaf70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;home_sample_1&lt;/div&gt;`)[0];
#                 popup_7aea6d0bf64788279230f9cb15ea7f60.setContent(html_22b9a128e725f96f4459388645daaf70);
#
#
#
#         marker_641e734c876a41ae22162bff058c18c3.bindPopup(popup_7aea6d0bf64788279230f9cb15ea7f60)
#         ;
#
#
#
#
#             var marker_fdc3413561cf17b96769ba9fb52e7dd1 = L.marker(
#                 [40.61266091930544, -111.94944674929728],
#                 {}
#             ).addTo(map_ef2f66e1f83d7914ecafd0fa8f515cb1);
#
#
#         var popup_de7712c8bfb76d6bc270498deb970e27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_457a766e5f1ca1d55c1be7fcce84ac9e = $(`&lt;div id=&quot;html_457a766e5f1ca1d55c1be7fcce84ac9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;home_sample_2&lt;/div&gt;`)[0];
#                 popup_de7712c8bfb76d6bc270498deb970e27.setContent(html_457a766e5f1ca1d55c1be7fcce84ac9e);
#
#
#
#         marker_fdc3413561cf17b96769ba9fb52e7dd1.bindPopup(popup_de7712c8bfb76d6bc270498deb970e27)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Perform a spatial join to find points that fall within polygons
gdf_joined = gpd.sjoin(gdf_points, saz_all_att, predicate='within'
                      ).sort_values(by=['label', 'low_grade']).reset_index()

# Display the result
gdf_joined.head()
# Out:
#    index   lat_left         lng                     geometry          label  \
# 0      0  40.597413 -111.935456  POINT (-111.93546 40.59741)  home_sample_0
# 1      0  40.597413 -111.935456  POINT (-111.93546 40.59741)  home_sample_0
# 2      0  40.597413 -111.935456  POINT (-111.93546 40.59741)  home_sample_0
# 3      1  40.601192 -111.879323  POINT (-111.87932 40.60119)  home_sample_1
# 4      1  40.601192 -111.879323  POINT (-111.87932 40.60119)  home_sample_1
#
#    index_right    obj_id                     obj_name obj_typ obj_subtcd  ...  \
# 0          141  16075468  RIVERSIDE ELEMENTARY SCHOOL  School        SAZ  ...
# 1          127  16075440    WEST JORDAN MIDDLE SCHOOL  School        SAZ  ...
# 2          143  16075472      WEST JORDAN HIGH SCHOOL  School        SAZ  ...
# 3            2  16074987  MIDVALLEY ELEMENTARY SCHOOL  School        SAZ  ...
# 4          105  16075399          UNION MIDDLE SCHOOL  School        SAZ  ...
#
#   eighth  ninth  tenth  eleventh  twelfth low_grade_att  high_grade_att  \
# 0  False  False  False     False    False            KG               6
# 1   True   True  False     False    False            07               9
# 2  False  False   True      True     True            10              12
# 3  False  False  False     False    False            KG               5
# 4   True  False  False     False    False            06               8
#
#    gender  school_typ ed_level
# 0     NaN           R       PM
# 1     NaN           R       MH
# 2     NaN           R        H
# 3     NaN           R        P
# 4     NaN           R        M
#
# [5 rows x 47 columns]

# %%
gdf_joined.columns
# Out:
# Index(['index', 'lat_left', 'lng', 'geometry', 'label', 'index_right',
#        'obj_id', 'obj_name', 'obj_typ', 'obj_subtcd', 'obj_subtyp', 'country',
#        'metro', 'lat_right', 'lon', 'reldate', 'obj_area', 'att_id',
#        'obj_id_pnt', 'low_grade', 'high_grade', 'nces_schid', 'nces_disid',
#        'grtschl_id', 'choice', 'coextensiv', 'students', 'teachers', 'pk',
#        'kg', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh',
#        'eighth', 'ninth', 'tenth', 'eleventh', 'twelfth', 'low_grade_att',
#        'high_grade_att', 'gender', 'school_typ', 'ed_level'],
#       dtype='object')

# %%
# view the results that we care about
gdf_joined[['label','geometry','obj_name','low_grade','high_grade']].sort_values(by=['label', 'low_grade'])
# Out:
#            label                     geometry                       obj_name  \
# 0  home_sample_0  POINT (-111.93546 40.59741)    RIVERSIDE ELEMENTARY SCHOOL
# 1  home_sample_0  POINT (-111.93546 40.59741)      WEST JORDAN MIDDLE SCHOOL
# 2  home_sample_0  POINT (-111.93546 40.59741)        WEST JORDAN HIGH SCHOOL
# 3  home_sample_1  POINT (-111.87932 40.60119)    MIDVALLEY ELEMENTARY SCHOOL
# 4  home_sample_1  POINT (-111.87932 40.60119)            UNION MIDDLE SCHOOL
# 5  home_sample_1  POINT (-111.87932 40.60119)          HILLCREST HIGH SCHOOL
# 6  home_sample_2  POINT (-111.94945 40.61266)  WEST JORDAN ELEMENTARY SCHOOL
# 7  home_sample_2  POINT (-111.94945 40.61266)      WEST JORDAN MIDDLE SCHOOL
# 8  home_sample_2  POINT (-111.94945 40.61266)        WEST JORDAN HIGH SCHOOL
#
#   low_grade  high_grade
# 0        KG           6
# 1        07           9
# 2        10          12
# 3        KG           5
# 4        06           8
# 5        09          12
# 6        KG           6
# 7        07           9
# 8        10          12

# %% [markdown]
# ### Prep for final plotting

# %% [markdown]
# #### Points

# %%
# clean up the table of points

# make a copy of the df using only the columns we care about
df = gdf_joined[['label','geometry','obj_name','low_grade','high_grade']].sort_values(
    by=['label', 'low_grade']).copy()

# consolidate all the school info columns into a single column
df['school'] = df.apply(lambda row: ''.join([str(row['obj_name'])
                          ,' [', str(row['low_grade']), ',', str(row['high_grade']),']']), axis=1)

# drop the (now redundant) columns
df = df.drop(columns=['obj_name','low_grade','high_grade'])

# further flatten all schoold into a single entry for simplified point creation later
# note that we use the HTML line break "<br>" as a delimiter because that's what leaflet will regonize
df['school_combined'] = df[['label','geometry','school']].groupby(['label','geometry'])['school'].transform(lambda x: ';<br>'.join(x))
df = df[['label','geometry','school_combined']].drop_duplicates()

gdf_joined_simple = df.copy().reset_index()
gdf_joined_simple
# Out:
#    index          label                     geometry  \
# 0      0  home_sample_0  POINT (-111.93546 40.59741)
# 1      3  home_sample_1  POINT (-111.87932 40.60119)
# 2      6  home_sample_2  POINT (-111.94945 40.61266)
#
#                                      school_combined
# 0  RIVERSIDE ELEMENTARY SCHOOL [KG,6];<br>WEST JO...
# 1  MIDVALLEY ELEMENTARY SCHOOL [KG,5];<br>UNION M...
# 2  WEST JORDAN ELEMENTARY SCHOOL [KG,6];<br>WEST ...

# %% [markdown]
# #### Polygons

# %%
# collect up the relevant boundary data

# go back to the saz_all_att df and grab only the school names that align with our sample points
names_to_match = gdf_joined['obj_name'].unique()

# Select rows from saz_att_all where "obj_name" matches any value in names_to_match
matching_rows = saz_all_att[saz_all_att['obj_name'].isin(names_to_match)].sort_values(by='obj_name')

# Display the selected rows
matching_rows[['obj_name','low_grade','high_grade','geometry']]
# Out:
#                           obj_name low_grade  high_grade  \
# 94           HILLCREST HIGH SCHOOL        09          12
# 2      MIDVALLEY ELEMENTARY SCHOOL        KG           5
# 141    RIVERSIDE ELEMENTARY SCHOOL        KG           6
# 105            UNION MIDDLE SCHOOL        06           8
# 144  WEST JORDAN ELEMENTARY SCHOOL        KG           6
# 143        WEST JORDAN HIGH SCHOOL        10          12
# 127      WEST JORDAN MIDDLE SCHOOL        07           9
#
#                                               geometry
# 94   POLYGON ((-111.87248 40.63011, -111.87203 40.6...
# 2    POLYGON ((-111.86597 40.62190, -111.86599 40.6...
# 141  POLYGON ((-111.92601 40.60880, -111.92527 40.6...
# 105  POLYGON ((-111.85871 40.61521, -111.85859 40.6...
# 144  POLYGON ((-111.94150 40.63127, -111.94116 40.6...
# 143  MULTIPOLYGON (((-112.05605 40.63124, -112.0546...
# 127  POLYGON ((-111.93793 40.63152, -111.93795 40.6...

# %% [markdown]
# # Display the final map
#
# This map should show schools associated with each location (point), as well as the ability to toggle each school attendance zone (polygon) on and off

# %%
# plot the results

from folium.plugins import MarkerCluster
import random

# create a base map centered on Salt Lake City, UT
m_final = folium.Map(
    location=[40.6, -111.9],
    zoom_start=12,
)

### SCHOOL ZONES

# Add each polygon to the map
for idx, row in matching_rows.iterrows():
    # generate a random display color
    random_color = '#{:06x}'.format(random.randint(0, 0xFFFFFF))
    # plot the polygon
    folium.GeoJson(row.geometry.__geo_interface__, name=row['obj_name'], show=False,
                   style_function=lambda x, color=random_color: {'fillColor': color, 'color': color}
                  ).add_to(m_final)

### SAMPLE POINTS

# Add annotated points to the map    
for idx, row in gdf_joined_simple.iterrows():
# for idx, row in gdf_joined.sample(1).iterrows():
    folium.Marker(location=[row.geometry.y, row.geometry.x], name=idx,
         popup=folium.Popup("<b>Location:</b> "+gdf_joined_simple.iloc[idx]['label']+"<br>"
                            "<b>Schools:</b> "+gdf_joined_simple.iloc[idx]['school_combined']+"<br>"
            ,max_width=500)
         ).add_to(m_final)

### LAYER CONTROL
folium.LayerControl(collapsed=False).add_to(m_final)

# display the map
m_final
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a42de30d29db710e474cce36b747dc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a42de30d29db710e474cce36b747dc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a42de30d29db710e474cce36b747dc3 = L.map(
#                 &quot;map_6a42de30d29db710e474cce36b747dc3&quot;,
#                 {
#                     center: [40.6, -111.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2426cd48e24dd037736112fade89865 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e2426cd48e24dd037736112fade89865.addTo(map_6a42de30d29db710e474cce36b747dc3);
#
#
#         function geo_json_61794aa1ace5a9d73b9d07a8f18acbcc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#5160fb&quot;, &quot;fillColor&quot;: &quot;#5160fb&quot;};
#             }
#         }
#
#         function geo_json_61794aa1ace5a9d73b9d07a8f18acbcc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_61794aa1ace5a9d73b9d07a8f18acbcc = L.geoJson(null, {
#                 onEachFeature: geo_json_61794aa1ace5a9d73b9d07a8f18acbcc_onEachFeature,
#
#                 style: geo_json_61794aa1ace5a9d73b9d07a8f18acbcc_styler,
#         });
#
#         function geo_json_61794aa1ace5a9d73b9d07a8f18acbcc_add (data) {
#             geo_json_61794aa1ace5a9d73b9d07a8f18acbcc
#                 .addData(data);
#         }
#             geo_json_61794aa1ace5a9d73b9d07a8f18acbcc_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-111.8724844, 40.6301142], [-111.8720306, 40.6301112], [-111.8711235, 40.630115], [-111.8688943, 40.6301245], [-111.8679219, 40.6301287], [-111.8659403, 40.6301358], [-111.8657552, 40.6301337], [-111.8647094, 40.6301347], [-111.8641767, 40.6301374], [-111.8635406, 40.6301407], [-111.8625075, 40.6301416], [-111.8623248, 40.6301418], [-111.8615177, 40.6301426], [-111.8612783, 40.630144], [-111.8607269, 40.6301472], [-111.860006, 40.6301542], [-111.8593913, 40.6301652], [-111.8587601, 40.6301865], [-111.8585638, 40.6301932], [-111.8580921, 40.6302152], [-111.8577247, 40.6302379], [-111.8574735, 40.6302535], [-111.8571979, 40.6302706], [-111.8568379, 40.6302963], [-111.856633, 40.6303108], [-111.8560997, 40.6303536], [-111.8559664, 40.6303644], [-111.855459, 40.6304069], [-111.8547545, 40.6304625], [-111.8547593, 40.6302988], [-111.8547418, 40.6301517], [-111.8547227, 40.6300172], [-111.8547252, 40.6296976], [-111.8547381, 40.6290862], [-111.8547442, 40.6285801], [-111.8547545, 40.6280467], [-111.8547596, 40.627453], [-111.8547643, 40.6268542], [-111.8547736, 40.626387], [-111.8547902, 40.6261011], [-111.8548425, 40.6258171], [-111.8549344, 40.6254281], [-111.8550325, 40.6250574], [-111.8551277, 40.6246743], [-111.8551828, 40.624457], [-111.8552317, 40.6242868], [-111.8552921, 40.6241102], [-111.8554302, 40.6237829], [-111.8554929, 40.6236231], [-111.8555725, 40.6233894], [-111.8556247, 40.6232058], [-111.8556412, 40.6230371], [-111.8556337, 40.6227705], [-111.8556321, 40.6225892], [-111.8555811, 40.6224426], [-111.8554954, 40.6219285], [-111.8554968, 40.6214838], [-111.8558216, 40.621529], [-111.8557744, 40.6213235], [-111.8557631, 40.621114], [-111.8558003, 40.6209059], [-111.8558715, 40.6207115], [-111.8559563, 40.6205645], [-111.8561705, 40.6202813], [-111.8565786, 40.6197841], [-111.8570109, 40.6192461], [-111.8574215, 40.6187473], [-111.8576342, 40.6184827], [-111.8577796, 40.6183018], [-111.8579079, 40.6181432], [-111.8580257, 40.6179977], [-111.8577044, 40.6179132], [-111.8573949, 40.6178259], [-111.8571688, 40.6177283], [-111.8569635, 40.6176182], [-111.8567759, 40.6174862], [-111.8566562, 40.6173846], [-111.8565649, 40.6172887], [-111.8564002, 40.6170821], [-111.8563221, 40.6169406], [-111.8562705, 40.6168202], [-111.8562244, 40.6166681], [-111.8561959, 40.6165194], [-111.8561903, 40.6163854], [-111.8561911, 40.6159467], [-111.856195, 40.6157475], [-111.8554606, 40.6157475], [-111.8551865, 40.6158112], [-111.8546899, 40.6157596], [-111.8543752, 40.6157463], [-111.8539714, 40.6158369], [-111.8535901, 40.6159702], [-111.852907, 40.6160795], [-111.8526139, 40.6161138], [-111.8520957, 40.6161218], [-111.8518473, 40.6161115], [-111.8516468, 40.6160684], [-111.851394, 40.6159843], [-111.8511845, 40.6158889], [-111.8506178, 40.6158208], [-111.8504678, 40.6157928], [-111.8492672, 40.615568], [-111.8477856, 40.6157945], [-111.8473957, 40.6157724], [-111.8477274, 40.6152188], [-111.8478542, 40.6146816], [-111.8477514, 40.6142733], [-111.8471834, 40.614108], [-111.8472295, 40.6138346], [-111.8473565, 40.6137208], [-111.8477552, 40.6135205], [-111.8477879, 40.6125641], [-111.8477887, 40.6120265], [-111.8477719, 40.6116672], [-111.8
